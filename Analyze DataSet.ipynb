# %%
import numpy as np
import pandas as pd
from keras.preprocessing.text import Tokenizer, text_to_word_sequence
from keras.preprocessing.sequence import pad_sequences
# Out:
# Using TensorFlow backend.

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# import dataset from txt file

X = np.array(())

DataSetPath = '/content/gdrive/My Drive/bsc/Final/DataSet/ferdousi_norm.txt'

dataset = pd.read_csv(DataSetPath, na_values=" ", header=None)
temp = dataset.iloc[:, 0].values

X = np.append(X, temp)

# %%
print(X[:3])
print(X[-1])
print(X[-2])
# Out:
# ['به نام خداوند جان و خرد' 'کزین برتر اندیشه برنگذرد'
#  'خداوند نام و خداوند جای']
# هر آنکس که دارد هش و رای و دین
# که تخم سخن من پراگنده ام

# %%
print("The total count of masraas is " , len(X))
# Out:
# The total count of masraas is  99217

# %%
if len(X) % 2 == 1:
    X = X[:-1]

# %%
print("The total count of masraas is " , len(X))
# Out:
# The total count of masraas is  99216

# %%
verses = []

for i in range(len(X)):
    if i % 2 == 0:
        verses.append(X[i] + ' ' + X[i + 1] + ' ')

# %%
print("The total number of verses is ", len(verses))
# Out:
# The total number of verses is  49608

# %%
# tokenize all data

tokenizer = Tokenizer(filters="")
tokenizer.fit_on_texts(verses)

TokenizedVerses = tokenizer.texts_to_sequences(verses)

# %%
word2index = tokenizer.word_index
index2word = tokenizer.index_word

# %%
print("Total number of unique words is ", len(word2index))
# Out:
# Total number of unique words is  17761

# %%
# find max length for padding

max_len = 0

for i in TokenizedVerses:
    if len(i) > max_len:
        sen = []
        for t in i :
            sen.append(index2word[t])
        print(sen)
    max_len = max(max_len, len(i)) 

print("maximum length of sentences : ", max_len)
# Out:
# ['به', 'نام', 'خداوند', 'جان', 'و', 'خرد', 'کزین', 'برتر', 'اندیشه', 'برنگذرد']
# ['خداوند', 'کیوان', 'و', 'گردان', 'سپهر', 'فروزنده', 'ماه', 'و', 'ناهید', 'و', 'مهر']
# ['نیابد', 'بدو', 'نیز', 'اندیشه', 'راه', 'که', 'او', 'برتر', 'از', 'نام', 'و', 'از', 'جایگاه']
# ['خرد', 'را', 'و', 'جان', 'را', 'همی', 'سنجد', 'اوی', 'در', 'اندیشه', 'سخته', 'کی', 'گنجد', 'اوی']
# ['سه', 'پاس', 'تو', 'چشم', 'است', 'وگوش', 'و', 'زبان', 'کزین', 'سه', 'رسد', 'نیک', 'و', 'بد', 'بی', 'گمان']
# ['نه', 'کند', 'آوری', 'گیرد', 'از', 'باج', 'و', 'گنج', 'نه', 'دل', 'تیره', 'دارد', 'ز', 'رزم', 'و', 'ز', 'رنج']
# ['ز', 'گنج', 'و', 'ز', 'تخت', 'و', 'ز', 'در', 'و', 'گهر', 'ز', 'اسپ', 'و', 'سلیح', 'و', 'کلاه', 'و', 'کمر']
# ['به', 'دیبا', 'و', 'دینار', 'و', 'در', 'و', 'درم', 'به', 'بوی', 'و', 'به', 'رنگ', 'و', 'به', 'هر', 'بیش', 'و', 'کم']
# ['نه', 'جا', 'هست', 'ما', 'را', 'نه', 'بوم', 'و', 'نه', 'بر', 'نه', 'سیم', 'و', 'سرای', 'و', 'نه', 'گاو', 'و', 'نه', 'خر']
# maximum length of sentences :  20

# %%
# do padding

_input_seq = pad_sequences(TokenizedVerses, maxlen=max_len, padding='post')
