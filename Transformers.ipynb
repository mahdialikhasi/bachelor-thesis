# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.text import Tokenizer, text_to_word_sequence
from keras.preprocessing.sequence import pad_sequences
from tensorflow.keras import layers
from tensorflow.keras.layers import ELU, Embedding, Dense, Dropout, Input, Layer, LayerNormalization
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.initializers import GlorotUniform
from tensorflow.keras.optimizers import SGD, RMSprop, Adam
from tensorflow.keras import regularizers, losses
from tensorflow.keras import backend as K

# %tensorflow_version 2.x

import os
import datetime
import random
import sys

tf.compat.v1.disable_eager_execution()
# Out:
# Using TensorFlow backend.

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# import dataset from txt file

X = np.array(())

DataSetPath = '/content/gdrive/My Drive/bsc/Final/DataSet/ferdousi_norm.txt'

dataset = pd.read_csv(DataSetPath, na_values=" ", header=None)
temp = dataset.iloc[:, 0].values

X = np.append(X, temp)

# %%
print(X[:3])
print(X[-1])
print(X[-2])
# Out:
# ['به نام خداوند جان و خرد' 'کزین برتر اندیشه برنگذرد'
#  'خداوند نام و خداوند جای']
# هر آنکس که دارد هش و رای و دین
# که تخم سخن من پراگنده ام

# %%
print("The total count of masraas is " , len(X))
# Out:
# The total count of masraas is  99217

# %%
# Train on just a quarter of data
X = X[: int(len(X) / 4) ]

if len(X) % 2 == 1:
    X = X[:-1]

# %%
print("The total count of masraas is " , len(X))
# Out:
# The total count of masraas is  24804

# %%
verses = []
input_verses = []
output_verses = []

for i in range(len(X)):
    if i % 2 == 0:
        input_verses.append('<sos> ' + X[i] + ' <middle> ' + X[i + 1])
        output_verses.append(X[i] + ' <middle> ' + X[i + 1] + ' <eos>')
        verses.append('<sos> ' + X[i] + ' <middle> ' + X[i + 1] + ' <eos>')

# %%
print("The total number of verses is ", len(verses))
# Out:
# The total number of verses is  12402

# %%
# tokenize all data

tokenizer = Tokenizer(filters="")
tokenizer.fit_on_texts(verses)

TokenizedVerses = tokenizer.texts_to_sequences(verses)
tokenized_input = tokenizer.texts_to_sequences(input_verses)
tokenized_output = tokenizer.texts_to_sequences(output_verses)

# %%
word2index = tokenizer.word_index
index2word = tokenizer.index_word

# %%
# find max length for padding

max_len = 0

for i in TokenizedVerses:
    if len(i) > max_len:
        sen = []
        for t in i :
            sen.append(index2word[t])
        print(sen)
    max_len = max(max_len, len(i)) 

max_len -= 1
print("maximum length of sentences : ", max_len)
# Out:
# ['<sos>', 'به', 'نام', 'خداوند', 'جان', 'و', 'خرد', '<middle>', 'کزین', 'برتر', 'اندیشه', 'برنگذرد', '<eos>']
# ['<sos>', 'خداوند', 'کیوان', 'و', 'گردان', 'سپهر', '<middle>', 'فروزنده', 'ماه', 'و', 'ناهید', 'و', 'مهر', '<eos>']
# ['<sos>', 'نیابد', 'بدو', 'نیز', 'اندیشه', 'راه', '<middle>', 'که', 'او', 'برتر', 'از', 'نام', 'و', 'از', 'جایگاه', '<eos>']
# ['<sos>', 'خرد', 'را', 'و', 'جان', 'را', 'همی', 'سنجد', 'اوی', '<middle>', 'در', 'اندیشه', 'سخته', 'کی', 'گنجد', 'اوی', '<eos>']
# ['<sos>', 'سه', 'پاس', 'تو', 'چشم', 'است', 'وگوش', 'و', 'زبان', '<middle>', 'کزین', 'سه', 'رسد', 'نیک', 'و', 'بد', 'بی', 'گمان', '<eos>']
# ['<sos>', 'نه', 'کند', 'آوری', 'گیرد', 'از', 'باج', 'و', 'گنج', '<middle>', 'نه', 'دل', 'تیره', 'دارد', 'ز', 'رزم', 'و', 'ز', 'رنج', '<eos>']
# ['<sos>', 'ز', 'گنج', 'و', 'ز', 'تخت', 'و', 'ز', 'در', 'و', 'گهر', '<middle>', 'ز', 'اسپ', 'و', 'سلیح', 'و', 'کلاه', 'و', 'کمر', '<eos>']
# ['<sos>', 'به', 'دیبا', 'و', 'دینار', 'و', 'در', 'و', 'درم', '<middle>', 'به', 'بوی', 'و', 'به', 'رنگ', 'و', 'به', 'هر', 'بیش', 'و', 'کم', '<eos>']
# maximum length of sentences :  21

# %%
# do padding

input_seq = pad_sequences(tokenized_input, maxlen=max_len, padding='post')
output_seq = pad_sequences(tokenized_output, maxlen=max_len, padding='post')

# %%
# Implement multi head self attention as a Keras layer

class MultiHeadSelfAttention(Layer):
    def __init__(self, embed_dim, num_heads=8):
        super(MultiHeadSelfAttention, self).__init__()
        self.embed_dim = embed_dim
        self.num_heads = num_heads
        
        self.query_dense = []
        for i in range(num_heads):
            self.query_dense.append(layers.Dense(embed_dim))
        
        self.key_dense = []
        for i in range(num_heads):
            self.key_dense.append(layers.Dense(embed_dim))
        
        self.value_dense = []
        for i in range(num_heads):
            self.value_dense.append(layers.Dense(embed_dim))

        self.combine_heads = layers.Dense(embed_dim)
    
    def self_attention(self, query, key, value):
        score = tf.matmul(query, key, transpose_b=True)
        dim_key = tf.cast(tf.shape(key)[-1], tf.float32)
        scaled_score = score / tf.math.sqrt(dim_key)
        weights = tf.nn.softmax(scaled_score, axis=-1)
        output = tf.matmul(weights, value)
        return output
    
    def call(self, inputs):
        # x.shape = [batch_size, seq_len, embedding_dim]
        batch_size = tf.shape(inputs)[0]
        seq_len = tf.shape(inputs)[1]

        query = []
        for i in range(self.num_heads):
            query.append(self.query_dense[i](inputs))
        
        key = []
        for i in range(self.num_heads):
            key.append(self.key_dense[i](inputs))
        
        value = []
        for i in range(self.num_heads):
            value.append(self.value_dense[i](inputs))

        attention = []
        for i in range(self.num_heads):
            attention.append(self.self_attention(query[i], key[i], value[i]))

        attention = tf.concat(attention, 2)
        # (batch_size, seq_len, embed_dim * num_head)

        output = self.combine_heads(
            attention
        )  # (batch_size, seq_len, embed_dim)
        return output

# %%
# Implement a Transformer block as a layer

class TransformerBlock(Layer):
    def __init__(self, embed_dim, num_heads, ff_dim, rate=0.1):
        super(TransformerBlock, self).__init__()
        self.att = MultiHeadSelfAttention(embed_dim, num_heads)
        self.ffn = Sequential(
            [Dense(ff_dim, activation="relu"), Dense(embed_dim),]
        )
        # self.layernorm1 = LayerNormalization(epsilon=1e-6)
        # self.layernorm2 = LayerNormalization(epsilon=1e-6)
        self.dropout1 = Dropout(rate)
        self.dropout2 = Dropout(rate)

    def call(self, inputs):
        attn_output = self.att(inputs)
        attn_output = self.dropout1(attn_output)
        # out1 = self.layernorm1(inputs + attn_output)
        # ffn_output = self.ffn(out1)
        ffn_output = self.ffn(attn_output)
        ffn_output = self.dropout2(ffn_output)
        # return self.layernorm2(out1 + ffn_output)
        return ffn_output

# %%
# Implement embedding layer

class TokenAndPositionEmbedding(Layer):
    def __init__(self, maxlen, vocab_size, embed_dim):
        super(TokenAndPositionEmbedding, self).__init__()
        self.token_emb = Embedding(input_dim=vocab_size, output_dim=embed_dim)
        self.pos_emb = Embedding(input_dim=maxlen, output_dim=embed_dim)

    def call(self, x):
        maxlen = tf.shape(x)[-1]
        positions = tf.range(start=0, limit=maxlen, delta=1)
        positions = self.pos_emb(positions)
        x = self.token_emb(x)
        return x + positions

# %%
# building model

def build_model(word_num, maxlen, embed_dim = 64, word_embedding_size = 512, num_heads = 8, feed_forward_dim = 128):
    inputs = Input(shape=(maxlen,), dtype=tf.int32)
    embedding_layer = TokenAndPositionEmbedding(maxlen, word_num, word_embedding_size)
    x = embedding_layer(inputs)
    x = TransformerBlock(embed_dim, num_heads, feed_forward_dim)(x)
    x = Dropout(0.1)(x)
    x = TransformerBlock(embed_dim, num_heads, feed_forward_dim)(x)
    x = Dropout(0.1)(x)
    # x = TransformerBlock(embed_dim, num_heads, feed_forward_dim)(x)
    # x = Dropout(0.1)(x)
    # x = TransformerBlock(embed_dim, num_heads, feed_forward_dim)(x)
    # x = Dropout(0.1)(x)
    # x = TransformerBlock(embed_dim, num_heads, feed_forward_dim)(x)
    # x = Dropout(0.1)(x)
    outputs = Dense(word_num, activation="softmax")(x)
    model = keras.Model(inputs=inputs, outputs=outputs)
    model.compile(
        "adam", loss="sparse_categorical_crossentropy"
    )
    model.summary()
    return model

# %%
base_path = "/content/gdrive/My Drive/bsc/Final/Transformers/"
# !ls "/content/gdrive/My Drive/bsc/Final/Transformers/"
# Out:
# acc.txt			     cp.ckpt.index
# checkpoint		     loss.txt
# cp.ckpt.data-00000-of-00002  sample_sentences_during_training.txt
# cp.ckpt.data-00001-of-00002

# %%
# sample from model

def sample_line(model, type = 0):
    sos = word2index['<sos>']
    eos = word2index['<eos>']
    middle = word2index['<middle>']
    
    _row = np.repeat(0, max_len)
    _row[0] = sos
    np_input = _row.reshape(1,max_len)

    output_sentence = []
    
    
    for i in range(1, max_len):
        o = model.predict(np_input)
        
        probs = np.array(o[0][i])
        probs[0] = 0
        if type == 0:
            probs /= probs.sum()
            idx = np.random.choice(len(probs), p=probs)
        
        elif type == 1:
            idx = np.argmax(probs)
        
        np_input[0, i] = idx
    
    sentence = np_input[0]

    for i in sentence:
        if i == sos:
            continue
        if i == eos:
            break
        if i == 0:
            continue
        if i == middle:
            output_sentence.append("    -   ")
        else:
            output_sentence.append(index2word[i])

    decoded_review = ' '.join(output_sentence)

    return decoded_review

# %%
# create custom callback
class MyCustomCallback(tf.keras.callbacks.Callback):
    def __init__(self, initial_epoch = 0):
        self.initial_epoch = initial_epoch

    def on_epoch_end(self, epoch, logs=None):
        print('Training: epoch {} ends at {}'.format(epoch + self.initial_epoch, datetime.datetime.now().time()))
        print('sample text via predict : ')
        sentence = sample_line(self.model, 0)
        print(sentence)
        
        _path = base_path + "sample_sentences_during_training.txt"
        file_object = open(_path, 'a+')
        file_object.write('\n Training: epoch {} ends at {} \n'.format(epoch + self.initial_epoch, datetime.datetime.now().time()))
        file_object.write('sample text via predict : \n')
        file_object.write(sentence)
        file_object.close()

# %%
# create custom callback to save loss and acc

class MyCustomCallbackLoss(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):    
        loss_path = base_path + "loss.txt"
        # acc_path = base_path + "acc.txt"
        print("saving loss")
        file_object = open(loss_path, 'a+')
        file_object.write('{}\n'.format(logs["loss"]))
        file_object.close()
        # file_object = open(acc_path, 'a+')
        # file_object.write('{}\n'.format(logs["sparse_categorical_accuracy"]))
        # file_object.close()

# %%
# train model

EPOCH_TIME = 100
WORD_NUM = len(index2word) + 1

# Create a callback that saves the model's weights
checkpoint_path = base_path + "cp.ckpt" 
checkpoint_dir = os.path.dirname(checkpoint_path)
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path, verbose=1, save_weights_only=True)

model = build_model(word_num = WORD_NUM, maxlen = max_len)

model.fit(input_seq, output_seq, batch_size=100, epochs = EPOCH_TIME, validation_split= 0.2, shuffle=True, verbose=1,
          callbacks=[
                     cp_callback,
                     MyCustomCallback(),
                     MyCustomCallbackLoss()
                    ]
          )
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 21)]              0
# _________________________________________________________________
# token_and_position_embedding (None, 21, 512)           4190208
# _________________________________________________________________
# transformer_block_3 (Transfo (None, 21, 64)            837376
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 21, 64)            0
# _________________________________________________________________
# transformer_block_4 (Transfo (None, 21, 64)            149248
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 21, 64)            0
# _________________________________________________________________
# dense_136 (Dense)            (None, 21, 8163)          530595
# =================================================================
# Total params: 5,707,427
# Trainable params: 5,707,427
# Non-trainable params: 0
# _________________________________________________________________
# Train on 9921 samples, validate on 2481 samples
# Epoch 1/100
# 9921/9921 [==============================] - ETA: 0s - loss: 5.3320
# Epoch 00001: saving model to /content/gdrive/My Drive/bsc/Final/Transformers/cp.ckpt
# Training: epoch 0 ends at 06:23:40.877067
# sample text via predict :
#     -
# saving loss
# 9921/9921 [==============================] - 123s 12ms/sample - loss: 5.3320 - val_loss: 4.8385
# Epoch 2/100
# 9921/9921 [==============================] - ETA: 0s - loss: 4.8377
# Epoch 00002: saving model to /content/gdrive/My Drive/bsc/Final/Transformers/cp.ckpt
# Training: epoch 1 ends at 06:25:45.292365
# sample text via predict :
# کمربند را آمد به
# saving loss
# 9921/9921 [==============================] - 122s 12ms/sample - loss: 4.8377 - val_loss: 4.8729
# Epoch 3/100
# 9921/9921 [==============================] - ETA: 0s - loss: 4.8232
# Epoch 00003: saving model to /content/gdrive/My Drive/bsc/Final/Transformers/cp.ckpt
# Training: epoch 2 ends at 06:27:48.032927
# sample text via predict :
# چه سخنها این فر و گرز به دید تا
# saving loss
# 9921/9921 [==============================] - 122s 12ms/sample - loss: 4.8232 - val_loss: 4.8879
# Epoch 4/100
# 9921/9921 [==============================] - ETA: 0s - loss: 4.6891
# Epoch 00004: saving model to /content/gdrive/My Drive/bsc/Final/Transformers/cp.ckpt
# Training: epoch 3 ends at 06:29:50.500101
# sample text via predict :
#     -
# saving loss
# 9921/9921 [==============================] - 121s 12ms/sample - loss: 4.6891 - val_loss: 4.2448
# Epoch 5/100
# 9921/9921 [==============================] - ETA: 0s - loss: 4.1698
# Epoch 00005: saving model to /content/gdrive/My Drive/bsc/Final/Transformers/cp.ckpt
# Training: epoch 4 ends at 06:31:53.941658
# sample text via predict :
#
# saving loss
# 9921/9921 [==============================] - 122s 12ms/sample - loss: 4.1698 - val_loss: 4.1853
# Epoch 6/100
# 9921/9921 [==============================] - ETA: 0s - loss: 4.0713
# Epoch 00006: saving model to /content/gdrive/My Drive/bsc/Final/Transformers/cp.ckpt
# Training: epoch 5 ends at 06:34:00.575609
# sample text via predict :
# بدان گویا به
# saving loss
# 9921/9921 [==============================] - 125s 13ms/sample - loss: 4.0713 - val_loss: 4.0465
# Epoch 7/100
# 9921/9921 [==============================] - ETA: 0s - loss: 3.8684
# Epoch 00007: saving model to /content/gdrive/My Drive/bsc/Final/Transformers/cp.ckpt
# Training: epoch 6 ends at 06:36:02.902590
# sample text via predict :
# پرنگار جهان گل که آمدست گرز بخت خواه
# saving loss
# 9921/9921 [==============================] - 121s 12ms/sample - loss: 3.8684 - val_loss: 3.8349
# Epoch 8/100
# 9921/9921 [==============================] - ETA: 0s - loss: 3.6387
# Epoch 00008: saving model to /content/gdrive/My Drive/bsc/Final/Transformers/cp.ckpt
# Training: epoch 7 ends at 06:38:05.499625
# sample text via predict :
# ای گفت من تو کز من خرد تو گفت
# saving loss
# 9921/9921 [==============================] - 121s 12ms/sample - loss: 3.6387 - val_loss: 3.6120
# Epoch 9/100
# 9921/9921 [==============================] - ETA: 0s - loss: 3.0375
# Epoch 00009: saving model to /content/gdrive/My Drive/bsc/Final/Transformers/cp.ckpt
# Training: epoch 8 ends at 06:40:08.853827
# sample text via predict :
# این
# saving loss
# 9921/9921 [==============================] - 122s 12ms/sample - loss: 3.0375 - val_loss: 2.3293
# Epoch 10/100
# 9921/9921 [==============================] - ETA: 0s - loss: 2.0072
# Epoch 00010: saving model to /content/gdrive/My Drive/bsc/Final/Transformers/cp.ckpt
# Training: epoch 9 ends at 06:42:11.783486
# sample text via predict :
#
# saving loss
# 9921/9921 [==============================] - 122s 12ms/sample - loss: 2.0072 - val_loss: 1.6663
# Epoch 11/100
# 9921/9921 [==============================] - ETA: 0s - loss: 1.5925
# Epoch 00011: saving model to /content/gdrive/My Drive/bsc/Final/Transformers/cp.ckpt
# Training: epoch 10 ends at 06:44:20.307366
# sample text via predict :
#
# saving loss
# 9921/9921 [==============================] - 127s 13ms/sample - loss: 1.5925 - val_loss: 1.4093
# Epoch 12/100
# 9921/9921 [==============================] - ETA: 0s - loss: 1.3476
# Epoch 00012: saving model to /content/gdrive/My Drive/bsc/Final/Transformers/cp.ckpt
# Training: epoch 11 ends at 06:46:23.584816
# sample text via predict :
# دارد دارد گفتی گفتی گفتی گفتی گفتی گفتی گفتی گفتی گفتی گفتی گفتی گفتی گفتی گفتی گفتی گفتی گفتی گفتی
# saving loss
# 9921/9921 [==============================] - 122s 12ms/sample - loss: 1.3476 - val_loss: 1.1771
# Epoch 13/100
# 9921/9921 [==============================] - ETA: 0s - loss: 1.1282
# Epoch 00013: saving model to /content/gdrive/My Drive/bsc/Final/Transformers/cp.ckpt
# Training: epoch 12 ends at 06:48:27.001438
# sample text via predict :
# مهر دارد گفتی گفتی گفتی گفتی گفتی گفتی نه این این نه نیست نیست نیست نه نیست نیست نیست این
# saving loss
# 9921/9921 [==============================] - 122s 12ms/sample - loss: 1.1282 - val_loss: 1.0111
# Epoch 14/100
# 9921/9921 [==============================] - ETA: 0s - loss: 0.9837
# Epoch 00014: saving model to /content/gdrive/My Drive/bsc/Final/Transformers/cp.ckpt
# Training: epoch 13 ends at 06:50:30.525642
# sample text via predict :
# دارد دارد دارد دارد دارد دارد گفتی گفتی گفتی نیست نیست نیست نیست نیست نیست نیست نیست نیست نیست نیست
# saving loss
# 9921/9921 [==============================] - 122s 12ms/sample - loss: 0.9837 - val_loss: 0.9293
# Epoch 15/100
# 9921/9921 [==============================] - ETA: 0s - loss: 0.8894
# Epoch 00015: saving model to /content/gdrive/My Drive/bsc/Final/Transformers/cp.ckpt
# Training: epoch 14 ends at 06:52:33.732940
# sample text via predict :
# بنده دارد دارد دارد دارد دارد دارد دارد گفتی دارد
# saving loss
# 9921/9921 [==============================] - 122s 12ms/sample - loss: 0.8894 - val_loss: 0.8447
# Epoch 16/100
# 9921/9921 [==============================] - ETA: 0s - loss: 0.8109
# Epoch 00016: saving model to /content/gdrive/My Drive/bsc/Final/Transformers/cp.ckpt
# Training: epoch 15 ends at 06:54:36.792826
# sample text via predict :
# بنده بنده بنده جفت مهان گفتی گفتی نیست نیست نه نه نه نیست نیست نیست نیست نیست نیست نیست نیست
# saving loss
# 9921/9921 [==============================] - 122s 12ms/sample - loss: 0.8109 - val_loss: 0.7942
# Epoch 17/100
# 9921/9921 [==============================] - ETA: 0s - loss: 0.7410
# Epoch 00017: saving model to /content/gdrive/My Drive/bsc/Final/Transformers/cp.ckpt
# Training: epoch 16 ends at 06:56:40.150226
# sample text via predict :
# بنده جفت جفت جفت گفتی گفتی جفت نیست گفتی نیست نیست نه نیست نیست نیست نیست نیست نیست نیست نیست
# saving loss
# 9921/9921 [==============================] - 122s 12ms/sample - loss: 0.7410 - val_loss: 0.7303
# Epoch 18/100
# 9921/9921 [==============================] - ETA: 0s - loss: 0.6848
# Epoch 00018: saving model to /content/gdrive/My Drive/bsc/Final/Transformers/cp.ckpt
# Training: epoch 17 ends at 06:58:53.073143
# sample text via predict :
# بنده جفت گفتی گفتی گفتی گفتی گفتی گفتی گفتی نیست نیست نیست گفتی نیست نیست نیست نیست نیست نیست نیست
# saving loss
# 9921/9921 [==============================] - 132s 13ms/sample - loss: 0.6848 - val_loss: 0.6879
# Epoch 19/100
# 9921/9921 [==============================] - ETA: 0s - loss: 0.6322
# Epoch 00019: saving model to /content/gdrive/My Drive/bsc/Final/Transformers/cp.ckpt
# Training: epoch 18 ends at 07:01:08.863279
# sample text via predict :
# آورد بنده بنده جفت دارد جفت نیست نیست نیست نیست نیست نیست نیست نیست نیست نیست نیست نیست نیست نیست
# saving loss
# 9921/9921 [==============================] - 135s 14ms/sample - loss: 0.6322 - val_loss: 0.6553
# Epoch 20/100
# 9921/9921 [==============================] - ETA: 0s - loss: 0.5855
# Epoch 00020: saving model to /content/gdrive/My Drive/bsc/Final/Transformers/cp.ckpt
# Training: epoch 19 ends at 07:03:21.538194
# sample text via predict :
# روزگار گفتی گفتی گفتی گفتی گفتی گفتی گفتی گفتی گفتی گفتی گفتی گفتی نیست گفتی نیست نیست گفتی نیست گفتی
# saving loss
# 9921/9921 [==============================] - 131s 13ms/sample - loss: 0.5855 - val_loss: 0.6253
# Epoch 21/100
# 9921/9921 [==============================] - ETA: 0s - loss: 0.5488
# Epoch 00021: saving model to /content/gdrive/My Drive/bsc/Final/Transformers/cp.ckpt
# Training: epoch 20 ends at 07:05:42.579454
# sample text via predict :
# گفتی گفتی گفتی گفتی گفتی گفتی گفتی گفتی گفتی گفتی گفتی گفتی گفتی گفتی گفتی گفتی گفتی گفتی گفتی گفتی
# saving loss
# 9921/9921 [==============================] - 140s 14ms/sample - loss: 0.5488 - val_loss: 0.5995
# Epoch 22/100
# 9921/9921 [==============================] - ETA: 0s - loss: 0.5176
# Epoch 00022: saving model to /content/gdrive/My Drive/bsc/Final/Transformers/cp.ckpt
# Training: epoch 21 ends at 07:07:55.391623
# sample text via predict :
# جست کام کام کام گفتی گفتی گفتی گفتی گفتی گفتی دارد دارد دارد نیست نیست نیست نیست نیست گفتی نیست
# saving loss
# 9921/9921 [==============================] - 131s 13ms/sample - loss: 0.5176 - val_loss: 0.5804
# Epoch 23/100
# 9921/9921 [==============================] - ETA: 0s - loss: 0.4877
# Epoch 00023: saving model to /content/gdrive/My Drive/bsc/Final/Transformers/cp.ckpt
# Training: epoch 22 ends at 07:09:59.131158
# sample text via predict :
# روزگار آورد گفتی گفتی گفتی گفتی گفتی گفتی گفتی گفتی گفتی گفتی گفتی نیست نیست نیست نیست نیست گفتی نیست
# saving loss
# 9921/9921 [==============================] - 123s 12ms/sample - loss: 0.4877 - val_loss: 0.5682
# Epoch 24/100
# 9921/9921 [==============================] - ETA: 0s - loss: 0.4582
# Epoch 00024: saving model to /content/gdrive/My Drive/bsc/Final/Transformers/cp.ckpt
# Training: epoch 23 ends at 07:12:02.641680
# sample text via predict :
# کام کام کام گفتی نیست گفتی گفتی نیست نیست گفتی گفتی نیست نیست نیست نیست نیست نیست نیست نیست نیست
# saving loss
# 9921/9921 [==============================] - 122s 12ms/sample - loss: 0.4582 - val_loss: 0.5519
# Epoch 25/100
# 9921/9921 [==============================] - ETA: 0s - loss: 0.4369
# Epoch 00025: saving model to /content/gdrive/My Drive/bsc/Final/Transformers/cp.ckpt
# Training: epoch 24 ends at 07:14:05.773525
# sample text via predict :
# جست جست گفتی گفتی گفتی گفتی گفتی گفتی گفتی گفتی نیست نیست گفتی نیست نیست نبرد نیست نبرد نبرد نبرد
# saving loss
# 9921/9921 [==============================] - 122s 12ms/sample - loss: 0.4369 - val_loss: 0.5421
# Epoch 26/100
# 9921/9921 [==============================] - ETA: 0s - loss: 0.4216
# Epoch 00026: saving model to /content/gdrive/My Drive/bsc/Final/Transformers/cp.ckpt
# Training: epoch 25 ends at 07:16:09.222425
# sample text via predict :
# کام کام کام گفتی گفتی گفتی گفتی گفتی نیست نیست نیست نیست گفتی نیست نیست نیست نیست نیست نیست نیست
# saving loss
# 9921/9921 [==============================] - 122s 12ms/sample - loss: 0.4216 - val_loss: 0.5271
# Epoch 27/100
# 9921/9921 [==============================] - ETA: 0s - loss: 0.3947
# Epoch 00027: saving model to /content/gdrive/My Drive/bsc/Final/Transformers/cp.ckpt
# Training: epoch 26 ends at 07:18:13.543067
# sample text via predict :
# جست کام کام کام کام کام کام کام روزگار کام مهان داشت نبرد نبرد بدوی نبرد نبرد نبرد نبرد نبرد
# saving loss
# 9921/9921 [==============================] - 123s 12ms/sample - loss: 0.3947 - val_loss: 0.5134
# Epoch 28/100
# 9921/9921 [==============================] - ETA: 0s - loss: 0.3801
# Epoch 00028: saving model to /content/gdrive/My Drive/bsc/Final/Transformers/cp.ckpt
# Training: epoch 27 ends at 07:20:16.699343
# sample text via predict :
# کام کام کام گفتی کام کام مرا نیست نیست مرا مرا مرا مرا مرا نیست نبرد نبرد نبرد نبرد نبرد
# saving loss
# 9921/9921 [==============================] - 122s 12ms/sample - loss: 0.3801 - val_loss: 0.5044
# Epoch 29/100
# 9921/9921 [==============================] - ETA: 0s - loss: 0.3659
# Epoch 00029: saving model to /content/gdrive/My Drive/bsc/Final/Transformers/cp.ckpt
# Training: epoch 28 ends at 07:22:19.348692
# sample text via predict :
# بگذرد بگذرد بگذرد بگذرد بگذرد بگذرد بگذرد کارزار داشت مرا دان مرا مرا دان کارزار داشت داشت داشت داشت داشت
# saving loss
# 9921/9921 [==============================] - 122s 12ms/sample - loss: 0.3659 - val_loss: 0.4987
# Epoch 30/100
# 9921/9921 [==============================] - ETA: 0s - loss: 0.3502
# Epoch 00030: saving model to /content/gdrive/My Drive/bsc/Final/Transformers/cp.ckpt
# Training: epoch 29 ends at 07:24:21.951934
# sample text via predict :
# جست کام کام کام کام کام کام کام مرا مرا مرا مرا مرا مرا مرا مرا مرا مرا مرا نیاز
# saving loss
# 9921/9921 [==============================] - 121s 12ms/sample - loss: 0.3502 - val_loss: 0.4892
# Epoch 31/100
# 9921/9921 [==============================] - ETA: 0s - loss: 0.3362
# Epoch 00031: saving model to /content/gdrive/My Drive/bsc/Final/Transformers/cp.ckpt
# Training: epoch 30 ends at 07:26:24.404607
# sample text via predict :
# جست کام کام کام کام کام کام کام کام کام کام کام کام نبرد نبرد نبرد نبرد نبرد نبرد کارزار
# saving loss
# 9921/9921 [==============================] - 121s 12ms/sample - loss: 0.3362 - val_loss: 0.4796
# Epoch 32/100
# 9921/9921 [==============================] - ETA: 0s - loss: 0.3173
# Epoch 00032: saving model to /content/gdrive/My Drive/bsc/Final/Transformers/cp.ckpt
# Training: epoch 31 ends at 07:28:27.026918
# sample text via predict :
# روزگار روزگار کام کام کام کام کام کام روزگار روزگار کام گفتی کام نبرد نبرد نبرد نبرد نبرد نبرد نبرد
# saving loss
# 9921/9921 [==============================] - 121s 12ms/sample - loss: 0.3173 - val_loss: 0.4726
# Epoch 33/100
# 9921/9921 [==============================] - ETA: 0s - loss: 0.3056
# Epoch 00033: saving model to /content/gdrive/My Drive/bsc/Final/Transformers/cp.ckpt
# Training: epoch 32 ends at 07:30:29.746360
# sample text via predict :
# ام ام ام ام ام ام ام ام ام ام ام ام ام ام ام ام ام ام ام ام
# saving loss
# 9921/9921 [==============================] - 122s 12ms/sample - loss: 0.3056 - val_loss: 0.4635
# Epoch 34/100
# 9921/9921 [==============================] - ETA: 0s - loss: 0.2934
# Epoch 00034: saving model to /content/gdrive/My Drive/bsc/Final/Transformers/cp.ckpt
# Training: epoch 33 ends at 07:32:32.364713
# sample text via predict :
# کام کام کام کام کام کام کام کام کام کام نبرد کام داشت نبرد نبرد بگذرد ام نبرد داشت ام
# saving loss
# 9921/9921 [==============================] - 121s 12ms/sample - loss: 0.2934 - val_loss: 0.4574
# Epoch 35/100
# 9921/9921 [==============================] - ETA: 0s - loss: 0.2808
# Epoch 00035: saving model to /content/gdrive/My Drive/bsc/Final/Transformers/cp.ckpt
# Training: epoch 34 ends at 07:34:34.289102
# sample text via predict :
# جست کام کام کام کام کام ام ام کام کام نبرد کام داشت داشت نبرد ام نبرد ام نبرد نبرد
# saving loss
# 9921/9921 [==============================] - 121s 12ms/sample - loss: 0.2808 - val_loss: 0.4567
# Epoch 36/100
# 9921/9921 [==============================] - ETA: 0s - loss: 0.2694
# Epoch 00036: saving model to /content/gdrive/My Drive/bsc/Final/Transformers/cp.ckpt
# Training: epoch 35 ends at 07:36:40.439653
# sample text via predict :
# روزگار کام کام کام کام کام کام کام کام کام کام کام کام کام کام بگذرد کام بگذرد ام ام
# saving loss
# 9921/9921 [==============================] - 125s 13ms/sample - loss: 0.2694 - val_loss: 0.4501
# Epoch 37/100
# 9921/9921 [==============================] - ETA: 0s - loss: 0.2558
# Epoch 00037: saving model to /content/gdrive/My Drive/bsc/Final/Transformers/cp.ckpt
# Training: epoch 36 ends at 07:38:43.527112
# sample text via predict :
# روزگار کام کام کام کام کام کام کام کام کام کام مرا مرا مرا کارزار ام ام نبرد بگذرد ام
# saving loss
# 9921/9921 [==============================] - 122s 12ms/sample - loss: 0.2558 - val_loss: 0.4377
# Epoch 38/100
# 9921/9921 [==============================] - ETA: 0s - loss: 0.2443
# Epoch 00038: saving model to /content/gdrive/My Drive/bsc/Final/Transformers/cp.ckpt
# Training: epoch 37 ends at 07:40:46.771928
# sample text via predict :
# روزگار مهان مهان کام کام کام کام مهان مهان مهان مهان کام کام کام مهان بگذرد مهان مهان بگذرد بگذرد
# saving loss
# 9921/9921 [==============================] - 122s 12ms/sample - loss: 0.2443 - val_loss: 0.4357
# Epoch 39/100
# 9921/9921 [==============================] - ETA: 0s - loss: 0.2341
# Epoch 00039: saving model to /content/gdrive/My Drive/bsc/Final/Transformers/cp.ckpt
# Training: epoch 38 ends at 07:42:51.835606
# sample text via predict :
# کام کام کام کام کام کام کام کام کام کام نه کام کام نه نه کام کام کام کام کام
# saving loss
# 9921/9921 [==============================] - 124s 12ms/sample - loss: 0.2341 - val_loss: 0.4340
# Epoch 40/100
# 9921/9921 [==============================] - ETA: 0s - loss: 0.2264
# Epoch 00040: saving model to /content/gdrive/My Drive/bsc/Final/Transformers/cp.ckpt
# Training: epoch 39 ends at 07:45:03.543282
# sample text via predict :
# جست کام کام کام کام کام داشت کام جگر داشت داشت داشت داشت داشت داشت داشت داشت داشت داشت داشت
# saving loss
# 9921/9921 [==============================] - 131s 13ms/sample - loss: 0.2264 - val_loss: 0.4251
# Epoch 41/100
# 9921/9921 [==============================] - ETA: 0s - loss: 0.2171
# Epoch 00041: saving model to /content/gdrive/My Drive/bsc/Final/Transformers/cp.ckpt
# Training: epoch 40 ends at 07:47:15.094869
# sample text via predict :
# اژدها زن کام کام کام کام کام کام داشت کام داشت داشت داشت داشت داشت نبرد داشت نبرد داشت داشت
# saving loss
# 9921/9921 [==============================] - 129s 13ms/sample - loss: 0.2171 - val_loss: 0.4211
# Epoch 42/100
# 9921/9921 [==============================] - ETA: 0s - loss: 0.2048
# Epoch 00042: saving model to /content/gdrive/My Drive/bsc/Final/Transformers/cp.ckpt
# Training: epoch 41 ends at 07:49:30.368844
# sample text via predict :
# اژدها کام کام کام کام کام زن کام کام زن زن زن جگر جگر جگر جگر جگر جگر جگر جگر
# saving loss
# 9921/9921 [==============================] - 134s 13ms/sample - loss: 0.2048 - val_loss: 0.4194
# Epoch 43/100
# 9921/9921 [==============================] - ETA: 0s - loss: 0.1986
# Epoch 00043: saving model to /content/gdrive/My Drive/bsc/Final/Transformers/cp.ckpt
# Training: epoch 42 ends at 07:51:33.907077
# sample text via predict :
# جست کام کام کام کام کام کام کام کام کام کام داشت داشت داشت داشت داشت داشت داشت داشت داشت
# saving loss
# 9921/9921 [==============================] - 122s 12ms/sample - loss: 0.1986 - val_loss: 0.4188
# Epoch 44/100
# 9921/9921 [==============================] - ETA: 0s - loss: 0.1891
# Epoch 00044: saving model to /content/gdrive/My Drive/bsc/Final/Transformers/cp.ckpt
# Training: epoch 43 ends at 07:53:37.281039
# sample text via predict :
# کام کام کام کام کام کام کام کام کام کام کام کام زن زن داشت داشت داشت کام داشت کام
# saving loss
# 9921/9921 [==============================] - 122s 12ms/sample - loss: 0.1891 - val_loss: 0.4159
# Epoch 45/100
# 9921/9921 [==============================] - ETA: 0s - loss: 0.1817
# Epoch 00045: saving model to /content/gdrive/My Drive/bsc/Final/Transformers/cp.ckpt
# Training: epoch 44 ends at 07:55:44.357176
# sample text via predict :
# بگذرد کام کام کام کام کام کام کام کام کام کارزار کارزار کارزار کارزار کارزار بگذرد بگذرد بگذرد بگذرد بگذرد
# saving loss
# 9921/9921 [==============================] - 126s 13ms/sample - loss: 0.1817 - val_loss: 0.4125
# Epoch 46/100
# 9921/9921 [==============================] - ETA: 0s - loss: 0.1755
# Epoch 00046: saving model to /content/gdrive/My Drive/bsc/Final/Transformers/cp.ckpt
# Training: epoch 45 ends at 07:57:47.080920
# sample text via predict :
# اژدها کام کام کام کام کام کام بدوی بدوی کام کام کام کام کارزار کام بگذرد بدوی بدوی بگذرد بدوی
# saving loss
# 9921/9921 [==============================] - 122s 12ms/sample - loss: 0.1755 - val_loss: 0.4128
# Epoch 47/100
# 9921/9921 [==============================] - ETA: 0s - loss: 0.1713
# Epoch 00047: saving model to /content/gdrive/My Drive/bsc/Final/Transformers/cp.ckpt
# Training: epoch 46 ends at 07:59:50.796668
# sample text via predict :
# اژدها کام کام کام کام کام کارزار کارزار کارزار کام کارزار داشت داشت کام داشت نبرد نبرد نبرد نبرد نبرد
# saving loss
# 9921/9921 [==============================] - 123s 12ms/sample - loss: 0.1713 - val_loss: 0.4064
# Epoch 48/100
# 9921/9921 [==============================] - ETA: 0s - loss: 0.1644
# Epoch 00048: saving model to /content/gdrive/My Drive/bsc/Final/Transformers/cp.ckpt
# Training: epoch 47 ends at 08:01:54.869754
# sample text via predict :
# اژدها مهان مهان مهان نیاز خوش خوش جگر داشت جگر خوش خوش داشت خوش خوش خوش خوش خوش خوش خوش
# saving loss
# 9921/9921 [==============================] - 123s 12ms/sample - loss: 0.1644 - val_loss: 0.4017
# Epoch 49/100
# 9921/9921 [==============================] - ETA: 0s - loss: 0.1552
# Epoch 00049: saving model to /content/gdrive/My Drive/bsc/Final/Transformers/cp.ckpt
# Training: epoch 48 ends at 08:03:58.720646
# sample text via predict :
# پیر کام کام کام کام کام کام مرا کام کام کام مرا کام جگر نیاز نیاز نبرد نبرد نبرد نیاز
# saving loss
# 9921/9921 [==============================] - 123s 12ms/sample - loss: 0.1552 - val_loss: 0.4016
# Epoch 50/100
# 9921/9921 [==============================] - ETA: 0s - loss: 0.1525
# Epoch 00050: saving model to /content/gdrive/My Drive/bsc/Final/Transformers/cp.ckpt
# Training: epoch 49 ends at 08:06:05.850437
# sample text via predict :
# جست کام مهان کام نیاز کام کام کام کارزار کام کارزار کارزار کارزار کارزار نیاز نیاز نیاز نیاز نیاز نیاز
# saving loss
# 9921/9921 [==============================] - 126s 13ms/sample - loss: 0.1525 - val_loss: 0.4008
# Epoch 51/100
# 9921/9921 [==============================] - ETA: 0s - loss: 0.1475
# Epoch 00051: saving model to /content/gdrive/My Drive/bsc/Final/Transformers/cp.ckpt
# Training: epoch 50 ends at 08:08:08.915453
# sample text via predict :
# اژدها کام کام کام کام نبرد مرا کام کام کام کام کام داشت کام داشت نبرد نبرد نبرد نبرد نبرد
# saving loss
# 9921/9921 [==============================] - 122s 12ms/sample - loss: 0.1475 - val_loss: 0.3983
# Epoch 52/100
# 9921/9921 [==============================] - ETA: 0s - loss: 0.1418
# Epoch 00052: saving model to /content/gdrive/My Drive/bsc/Final/Transformers/cp.ckpt
# Training: epoch 51 ends at 08:10:12.298100
# sample text via predict :
# پیر کام کام کام کام کام کام کام کام کام کام کام کام کام کام نیاز کام کام کام کارزار
# saving loss
# 9921/9921 [==============================] - 122s 12ms/sample - loss: 0.1418 - val_loss: 0.3995
# Epoch 53/100
# 9921/9921 [==============================] - ETA: 0s - loss: 0.1387
# Epoch 00053: saving model to /content/gdrive/My Drive/bsc/Final/Transformers/cp.ckpt
# Training: epoch 52 ends at 08:12:15.126426
# sample text via predict :
# پیر پیر نبرد پیر نبرد نبرد نبرد نبرد کام نبرد نبرد نبرد جگر نبرد کام نیاز نبرد نبرد نبرد نیاز
# saving loss
# 9921/9921 [==============================] - 122s 12ms/sample - loss: 0.1387 - val_loss: 0.3971
# Epoch 54/100
# 9921/9921 [==============================] - ETA: 0s - loss: 0.1328
# Epoch 00054: saving model to /content/gdrive/My Drive/bsc/Final/Transformers/cp.ckpt
# Training: epoch 53 ends at 08:14:32.484116
# sample text via predict :
# رهنمون رهنمون نبرد نبرد نبرد نبرد بگذرد بگذرد نبرد نبرد بگذرد کام بدوی رهنمون رهنمون نبرد بگذرد نبرد نبرد نبرد
# saving loss
# 9921/9921 [==============================] - 136s 14ms/sample - loss: 0.1328 - val_loss: 0.3968
# Epoch 55/100
# 9921/9921 [==============================] - ETA: 0s - loss: 0.1303
# Epoch 00055: saving model to /content/gdrive/My Drive/bsc/Final/Transformers/cp.ckpt
# Training: epoch 54 ends at 08:16:56.067533
# sample text via predict :
# اژدها مهان مهان نبرد مهان جگر جگر جگر نبرد نبرد نبرد نبرد نبرد نبرد نبرد جگر نبرد نبرد نبرد نبرد
# saving loss
# 9921/9921 [==============================] - 142s 14ms/sample - loss: 0.1303 - val_loss: 0.3930
# Epoch 56/100
# 9921/9921 [==============================] - ETA: 0s - loss: 0.1240
# Epoch 00056: saving model to /content/gdrive/My Drive/bsc/Final/Transformers/cp.ckpt
# Training: epoch 55 ends at 08:19:07.140659
# sample text via predict :
# کام کام کام کام کام کام کام کام کام کام کام کام کام کام زن کام کام کام کام کام
# saving loss
# 9921/9921 [==============================] - 130s 13ms/sample - loss: 0.1240 - val_loss: 0.3942
# Epoch 57/100
# 9921/9921 [==============================] - ETA: 0s - loss: 0.1221
# Epoch 00057: saving model to /content/gdrive/My Drive/bsc/Final/Transformers/cp.ckpt
# Training: epoch 56 ends at 08:21:23.294159
# sample text via predict :
# اژدها کام کام کام کام کام کام کام کام کام زن زن زن زن کام بگذرد بگذرد بگذرد بگذرد بگذرد
# saving loss
# 9921/9921 [==============================] - 135s 14ms/sample - loss: 0.1221 - val_loss: 0.3964
# Epoch 58/100
# 9921/9921 [==============================] - ETA: 0s - loss: 0.1162
# Epoch 00058: saving model to /content/gdrive/My Drive/bsc/Final/Transformers/cp.ckpt
# Training: epoch 57 ends at 08:23:30.440592
# sample text via predict :
# پیر جگر نیاز رهنمون رهنمون رهنمون نبرد رهنمون رهنمون رهنمون رهنمون رهنمون بدوی نیاز نیاز نیاز رهنمون نیاز نیاز رهنمون
# saving loss
# 9921/9921 [==============================] - 126s 13ms/sample - loss: 0.1162 - val_loss: 0.3920
# Epoch 59/100
# 9921/9921 [==============================] - ETA: 0s - loss: 0.1135
# Epoch 00059: saving model to /content/gdrive/My Drive/bsc/Final/Transformers/cp.ckpt
# Training: epoch 58 ends at 08:25:37.172785
# sample text via predict :
# اژدها نیاز نیاز نیاز بدوی جایی نیاز نیاز نیاز جایی جایی جایی خوش بدوی بدوی کلید نیاز بدوی نیاز نیاز
# saving loss
# 9921/9921 [==============================] - 126s 13ms/sample - loss: 0.1135 - val_loss: 0.3929
# Epoch 60/100
# 9921/9921 [==============================] - ETA: 0s - loss: 0.1082
# Epoch 00060: saving model to /content/gdrive/My Drive/bsc/Final/Transformers/cp.ckpt
# Training: epoch 59 ends at 08:27:55.138229
# sample text via predict :
# اژدها نیاز نیاز نیاز رهنمون بدوی بدوی بدوی بدوی بدوی بگذرد بدوی بدوی بدوی بدوی نیاز نیاز نیاز نیاز نیاز
# saving loss
# 9921/9921 [==============================] - 137s 14ms/sample - loss: 0.1082 - val_loss: 0.3946
# Epoch 61/100
# 9921/9921 [==============================] - ETA: 0s - loss: 0.1111
# Epoch 00061: saving model to /content/gdrive/My Drive/bsc/Final/Transformers/cp.ckpt
# Training: epoch 60 ends at 08:30:03.502588
# sample text via predict :
# اژدها نیاز نیاز نیاز کلید کلید کلید کلید کلید کلید کلید بگذرد کلید نیاز کلید کلید کلید کلید کلید کلید
# saving loss
# 9921/9921 [==============================] - 127s 13ms/sample - loss: 0.1111 - val_loss: 0.3922
# Epoch 62/100
# 9921/9921 [==============================] - ETA: 0s - loss: 0.1031
# Epoch 00062: saving model to /content/gdrive/My Drive/bsc/Final/Transformers/cp.ckpt
# Training: epoch 61 ends at 08:32:26.091470
# sample text via predict :
# اژدها جگر جگر کام جگر کام کام کام کام جگر ناپدید ناپدید ناپدید کارزار ناپدید داشت جگر ناپدید ناپدید ناپدید
# saving loss
# 9921/9921 [==============================] - 141s 14ms/sample - loss: 0.1031 - val_loss: 0.3950
# Epoch 63/100
# 9921/9921 [==============================] - ETA: 0s - loss: 0.1009
# Epoch 00063: saving model to /content/gdrive/My Drive/bsc/Final/Transformers/cp.ckpt
# Training: epoch 62 ends at 08:34:50.024682
# sample text via predict :
# جست کام کام کام کام کام کام ناپدید کام ناپدید کام ناپدید کام بگذرد کام کام کام نیاز کام کام
# saving loss
# 9921/9921 [==============================] - 143s 14ms/sample - loss: 0.1009 - val_loss: 0.3926
# Epoch 64/100
# 9921/9921 [==============================] - ETA: 0s - loss: 0.0984
# Epoch 00064: saving model to /content/gdrive/My Drive/bsc/Final/Transformers/cp.ckpt
# Training: epoch 63 ends at 08:37:17.838056
# sample text via predict :
# اژدها زنده بگذرد بگذرد بگذرد بگذرد بگذرد بگذرد بگذرد بگذرد بگذرد بگذرد بگذرد بگذرد بگذرد بگذرد زنده بگذرد بگذرد بگذرد
# saving loss
# 9921/9921 [==============================] - 146s 15ms/sample - loss: 0.0984 - val_loss: 0.3893
# Epoch 65/100
# 9921/9921 [==============================] - ETA: 0s - loss: 0.0973
# Epoch 00065: saving model to /content/gdrive/My Drive/bsc/Final/Transformers/cp.ckpt
# Training: epoch 64 ends at 08:39:43.192775
# sample text via predict :
# رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون
# saving loss
# 9921/9921 [==============================] - 144s 15ms/sample - loss: 0.0973 - val_loss: 0.3908
# Epoch 66/100
# 9921/9921 [==============================] - ETA: 0s - loss: 0.0936
# Epoch 00066: saving model to /content/gdrive/My Drive/bsc/Final/Transformers/cp.ckpt
# Training: epoch 65 ends at 08:41:52.866349
# sample text via predict :
# اژدها جگر زنده زنده زنده رهنمون کام ناپدید کام ناپدید کام ناپدید ناپدید ناپدید ناپدید رهنمون رهنمون رهنمون رهنمون رهنمون
# saving loss
# 9921/9921 [==============================] - 128s 13ms/sample - loss: 0.0936 - val_loss: 0.3910
# Epoch 67/100
# 9921/9921 [==============================] - ETA: 0s - loss: 0.0906
# Epoch 00067: saving model to /content/gdrive/My Drive/bsc/Final/Transformers/cp.ckpt
# Training: epoch 66 ends at 08:44:02.560197
# sample text via predict :
# رهنمون زنده ناپدید روزگار رهنمون ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید
# saving loss
# 9921/9921 [==============================] - 129s 13ms/sample - loss: 0.0906 - val_loss: 0.3904
# Epoch 68/100
# 9921/9921 [==============================] - ETA: 0s - loss: 0.0929
# Epoch 00068: saving model to /content/gdrive/My Drive/bsc/Final/Transformers/cp.ckpt
# Training: epoch 67 ends at 08:46:36.048640
# sample text via predict :
# جست ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید
# saving loss
# 9921/9921 [==============================] - 152s 15ms/sample - loss: 0.0929 - val_loss: 0.3900
# Epoch 69/100
# 9921/9921 [==============================] - ETA: 0s - loss: 0.0908
# Epoch 00069: saving model to /content/gdrive/My Drive/bsc/Final/Transformers/cp.ckpt
# Training: epoch 68 ends at 08:48:55.166831
# sample text via predict :
# رهنمون راست جگر جگر ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید
# saving loss
# 9921/9921 [==============================] - 137s 14ms/sample - loss: 0.0908 - val_loss: 0.3879
# Epoch 70/100
# 9921/9921 [==============================] - ETA: 0s - loss: 0.0831
# Epoch 00070: saving model to /content/gdrive/My Drive/bsc/Final/Transformers/cp.ckpt
# Training: epoch 69 ends at 08:51:10.032478
# sample text via predict :
# جست ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید
# saving loss
# 9921/9921 [==============================] - 134s 13ms/sample - loss: 0.0831 - val_loss: 0.3903
# Epoch 71/100
# 9921/9921 [==============================] - ETA: 0s - loss: 0.0838
# Epoch 00071: saving model to /content/gdrive/My Drive/bsc/Final/Transformers/cp.ckpt
# Training: epoch 70 ends at 08:53:38.694978
# sample text via predict :
# رهنمون کام ناپدید رهنمون ناپدید رهنمون ناپدید ناپدید ناپدید ناپدید ناپدید رهنمون ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید
# saving loss
# 9921/9921 [==============================] - 147s 15ms/sample - loss: 0.0838 - val_loss: 0.3902
# Epoch 72/100
# 9921/9921 [==============================] - ETA: 0s - loss: 0.0826
# Epoch 00072: saving model to /content/gdrive/My Drive/bsc/Final/Transformers/cp.ckpt
# Training: epoch 71 ends at 08:56:07.302912
# sample text via predict :
# ناپدید زنده ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید
# saving loss
# 9921/9921 [==============================] - 147s 15ms/sample - loss: 0.0826 - val_loss: 0.3897
# Epoch 73/100
# 9921/9921 [==============================] - ETA: 0s - loss: 0.0787
# Epoch 00073: saving model to /content/gdrive/My Drive/bsc/Final/Transformers/cp.ckpt
# Training: epoch 72 ends at 08:58:32.066901
# sample text via predict :
# جست کام ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید
# saving loss
# 9921/9921 [==============================] - 143s 14ms/sample - loss: 0.0787 - val_loss: 0.3901
# Epoch 74/100
# 9921/9921 [==============================] - ETA: 0s - loss: 0.0780
# Epoch 00074: saving model to /content/gdrive/My Drive/bsc/Final/Transformers/cp.ckpt
# Training: epoch 73 ends at 09:00:53.445053
# sample text via predict :
# رهنمون ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید
# saving loss
# 9921/9921 [==============================] - 140s 14ms/sample - loss: 0.0780 - val_loss: 0.3861
# Epoch 75/100
# 9921/9921 [==============================] - ETA: 0s - loss: 0.0789
# Epoch 00075: saving model to /content/gdrive/My Drive/bsc/Final/Transformers/cp.ckpt
# Training: epoch 74 ends at 09:03:20.419435
# sample text via predict :
# ایزدی ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید
# saving loss
# 9921/9921 [==============================] - 146s 15ms/sample - loss: 0.0789 - val_loss: 0.3927
# Epoch 76/100
# 9921/9921 [==============================] - ETA: 0s - loss: 0.0786
# Epoch 00076: saving model to /content/gdrive/My Drive/bsc/Final/Transformers/cp.ckpt
# Training: epoch 75 ends at 09:05:47.177171
# sample text via predict :
# رهنمون کام رهنمون کام کام رهنمون کام کام کام زن کام جگر رهنمون رهنمون کام رهنمون رهنمون رهنمون کام کام
# saving loss
# 9921/9921 [==============================] - 145s 15ms/sample - loss: 0.0786 - val_loss: 0.3898
# Epoch 77/100
# 9921/9921 [==============================] - ETA: 0s - loss: 0.0784
# Epoch 00077: saving model to /content/gdrive/My Drive/bsc/Final/Transformers/cp.ckpt
# Training: epoch 76 ends at 09:08:15.105137
# sample text via predict :
# رهنمون رهنمون رهنمون ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید
# saving loss
# 9921/9921 [==============================] - 147s 15ms/sample - loss: 0.0784 - val_loss: 0.3867
# Epoch 78/100
# 9921/9921 [==============================] - ETA: 0s - loss: 0.0762
# Epoch 00078: saving model to /content/gdrive/My Drive/bsc/Final/Transformers/cp.ckpt
# Training: epoch 77 ends at 09:10:39.437521
# sample text via predict :
# رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون ناپدید رهنمون رهنمون رهنمون رهنمون شادمان رهنمون
# saving loss
# 9921/9921 [==============================] - 143s 14ms/sample - loss: 0.0762 - val_loss: 0.3912
# Epoch 79/100
# 9921/9921 [==============================] - ETA: 0s - loss: 0.0736
# Epoch 00079: saving model to /content/gdrive/My Drive/bsc/Final/Transformers/cp.ckpt
# Training: epoch 78 ends at 09:13:05.502860
# sample text via predict :
# رهنمون کام رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون ناپدید کام ناپدید رهنمون رهنمون ناپدید رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون
# saving loss
# 9921/9921 [==============================] - 145s 15ms/sample - loss: 0.0736 - val_loss: 0.3886
# Epoch 80/100
# 9921/9921 [==============================] - ETA: 0s - loss: 0.0709
# Epoch 00080: saving model to /content/gdrive/My Drive/bsc/Final/Transformers/cp.ckpt
# Training: epoch 79 ends at 09:15:23.348150
# sample text via predict :
# رهنمون زنده ناپدید رهنمون ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید
# saving loss
# 9921/9921 [==============================] - 137s 14ms/sample - loss: 0.0709 - val_loss: 0.3865
# Epoch 81/100
# 9921/9921 [==============================] - ETA: 0s - loss: 0.0704
# Epoch 00081: saving model to /content/gdrive/My Drive/bsc/Final/Transformers/cp.ckpt
# Training: epoch 80 ends at 09:17:51.717045
# sample text via predict :
# رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون
# saving loss
# 9921/9921 [==============================] - 147s 15ms/sample - loss: 0.0704 - val_loss: 0.3870
# Epoch 82/100
# 9921/9921 [==============================] - ETA: 0s - loss: 0.0681
# Epoch 00082: saving model to /content/gdrive/My Drive/bsc/Final/Transformers/cp.ckpt
# Training: epoch 81 ends at 09:19:59.260161
# sample text via predict :
# رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون
# saving loss
# 9921/9921 [==============================] - 126s 13ms/sample - loss: 0.0681 - val_loss: 0.3863
# Epoch 83/100
# 9921/9921 [==============================] - ETA: 0s - loss: 0.0687
# Epoch 00083: saving model to /content/gdrive/My Drive/bsc/Final/Transformers/cp.ckpt
# Training: epoch 82 ends at 09:22:14.676779
# sample text via predict :
# رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون ناپدید رهنمون رهنمون ناپدید رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون
# saving loss
# 9921/9921 [==============================] - 134s 14ms/sample - loss: 0.0687 - val_loss: 0.3821
# Epoch 84/100
# 9921/9921 [==============================] - ETA: 0s - loss: 0.0670
# Epoch 00084: saving model to /content/gdrive/My Drive/bsc/Final/Transformers/cp.ckpt
# Training: epoch 83 ends at 09:24:22.561400
# sample text via predict :
# رهنمون رهنمون رهنمون زن رهنمون رهنمون رهنمون رهنمون زن رهنمون رهنمون رهنمون رهنمون زن رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون
# saving loss
# 9921/9921 [==============================] - 127s 13ms/sample - loss: 0.0670 - val_loss: 0.3845
# Epoch 85/100
# 9921/9921 [==============================] - ETA: 0s - loss: 0.0644
# Epoch 00085: saving model to /content/gdrive/My Drive/bsc/Final/Transformers/cp.ckpt
# Training: epoch 84 ends at 09:26:31.403331
# sample text via predict :
# رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون
# saving loss
# 9921/9921 [==============================] - 128s 13ms/sample - loss: 0.0644 - val_loss: 0.3841
# Epoch 86/100
# 9921/9921 [==============================] - ETA: 0s - loss: 0.0644
# Epoch 00086: saving model to /content/gdrive/My Drive/bsc/Final/Transformers/cp.ckpt
# Training: epoch 85 ends at 09:28:45.173032
# sample text via predict :
# رهنمون رهنمون ناپدید رهنمون ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید
# saving loss
# 9921/9921 [==============================] - 132s 13ms/sample - loss: 0.0644 - val_loss: 0.3864
# Epoch 87/100
# 9921/9921 [==============================] - ETA: 0s - loss: 0.0642
# Epoch 00087: saving model to /content/gdrive/My Drive/bsc/Final/Transformers/cp.ckpt
# Training: epoch 86 ends at 09:31:08.535735
# sample text via predict :
# رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون ناپدید رهنمون رهنمون ناپدید ناپدید راست رهنمون رهنمون ناپدید ناپدید راست راست
# saving loss
# 9921/9921 [==============================] - 142s 14ms/sample - loss: 0.0642 - val_loss: 0.3816
# Epoch 88/100
# 9921/9921 [==============================] - ETA: 0s - loss: 0.0627
# Epoch 00088: saving model to /content/gdrive/My Drive/bsc/Final/Transformers/cp.ckpt
# Training: epoch 87 ends at 09:33:26.295800
# sample text via predict :
# رهنمون رهنمون ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید رهنمون ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید
# saving loss
# 9921/9921 [==============================] - 136s 14ms/sample - loss: 0.0627 - val_loss: 0.3887
# Epoch 89/100
# 9921/9921 [==============================] - ETA: 0s - loss: 0.0631
# Epoch 00089: saving model to /content/gdrive/My Drive/bsc/Final/Transformers/cp.ckpt
# Training: epoch 88 ends at 09:35:50.403399
# sample text via predict :
# رهنمون رهنمون رهنمون ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید
# saving loss
# 9921/9921 [==============================] - 143s 14ms/sample - loss: 0.0631 - val_loss: 0.3891
# Epoch 90/100
# 9921/9921 [==============================] - ETA: 0s - loss: 0.0632
# Epoch 00090: saving model to /content/gdrive/My Drive/bsc/Final/Transformers/cp.ckpt
# Training: epoch 89 ends at 09:38:19.361867
# sample text via predict :
# راست راست ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید
# saving loss
# 9921/9921 [==============================] - 148s 15ms/sample - loss: 0.0632 - val_loss: 0.3872
# Epoch 91/100
# 9921/9921 [==============================] - ETA: 0s - loss: 0.0611
# Epoch 00091: saving model to /content/gdrive/My Drive/bsc/Final/Transformers/cp.ckpt
# Training: epoch 90 ends at 09:40:45.706705
# sample text via predict :
# رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون
# saving loss
# 9921/9921 [==============================] - 145s 15ms/sample - loss: 0.0611 - val_loss: 0.3818
# Epoch 92/100
# 9921/9921 [==============================] - ETA: 0s - loss: 0.0585
# Epoch 00092: saving model to /content/gdrive/My Drive/bsc/Final/Transformers/cp.ckpt
# Training: epoch 91 ends at 09:43:08.594771
# sample text via predict :
# رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون
# saving loss
# 9921/9921 [==============================] - 142s 14ms/sample - loss: 0.0585 - val_loss: 0.3836
# Epoch 93/100
# 9921/9921 [==============================] - ETA: 0s - loss: 0.0571
# Epoch 00093: saving model to /content/gdrive/My Drive/bsc/Final/Transformers/cp.ckpt
# Training: epoch 92 ends at 09:45:43.977020
# sample text via predict :
# رهنمون رهنمون رهنمون ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید رهنمون ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید
# saving loss
# 9921/9921 [==============================] - 154s 16ms/sample - loss: 0.0571 - val_loss: 0.3864
# Epoch 94/100
# 9921/9921 [==============================] - ETA: 0s - loss: 0.0576
# Epoch 00094: saving model to /content/gdrive/My Drive/bsc/Final/Transformers/cp.ckpt
# Training: epoch 93 ends at 09:48:09.247863
# sample text via predict :
# رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون ناپدید رهنمون ناپدید ناپدید ناپدید ناپدید ناپدید رهنمون خواهی رهنمون رهنمون رهنمون رهنمون رهنمون
# saving loss
# 9921/9921 [==============================] - 144s 15ms/sample - loss: 0.0576 - val_loss: 0.3865
# Epoch 95/100
# 9921/9921 [==============================] - ETA: 0s - loss: 0.0551
# Epoch 00095: saving model to /content/gdrive/My Drive/bsc/Final/Transformers/cp.ckpt
# Training: epoch 94 ends at 09:50:18.838130
# sample text via predict :
# رهنمون رهنمون ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید
# saving loss
# 9921/9921 [==============================] - 128s 13ms/sample - loss: 0.0551 - val_loss: 0.3784
# Epoch 96/100
# 9921/9921 [==============================] - ETA: 0s - loss: 0.0538
# Epoch 00096: saving model to /content/gdrive/My Drive/bsc/Final/Transformers/cp.ckpt
# Training: epoch 95 ends at 09:52:42.253135
# sample text via predict :
# رهنمون زنده رهنمون رهنمون رهنمون رهنمون رهنمون رهنمون راست ناپدید رهنمون رهنمون راست رهنمون رهنمون راست رهنمون راست راست راست
# saving loss
# 9921/9921 [==============================] - 142s 14ms/sample - loss: 0.0538 - val_loss: 0.3813
# Epoch 97/100
# 9921/9921 [==============================] - ETA: 0s - loss: 0.0552
# Epoch 00097: saving model to /content/gdrive/My Drive/bsc/Final/Transformers/cp.ckpt
# Training: epoch 96 ends at 09:54:47.773929
# sample text via predict :
# راست راست خواهی خواهی رهنمون خواهی خواهی رهنمون ناپدید خواهی خواهی رهنمون ناپدید رهنمون خواهی رهنمون خواهی خواهی خواهی خواهی
# saving loss
# 9921/9921 [==============================] - 124s 13ms/sample - loss: 0.0552 - val_loss: 0.3821
# Epoch 98/100
# 9921/9921 [==============================] - ETA: 0s - loss: 0.0545
# Epoch 00098: saving model to /content/gdrive/My Drive/bsc/Final/Transformers/cp.ckpt
# Training: epoch 97 ends at 09:56:52.406837
# sample text via predict :
# رهنمون جگر جگر جگر جگر جگر جگر جگر جگر جگر جگر جگر جگر ناپدید جگر جگر جگر جگر جگر جگر
# saving loss
# 9921/9921 [==============================] - 123s 12ms/sample - loss: 0.0545 - val_loss: 0.3788
# Epoch 99/100
# 9921/9921 [==============================] - ETA: 0s - loss: 0.0532
# Epoch 00099: saving model to /content/gdrive/My Drive/bsc/Final/Transformers/cp.ckpt
# Training: epoch 98 ends at 09:59:01.701645
# sample text via predict :
# بلا زنده ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید ناپدید
# saving loss
# 9921/9921 [==============================] - 128s 13ms/sample - loss: 0.0532 - val_loss: 0.3802
# Epoch 100/100
# 9921/9921 [==============================] - ETA: 0s - loss: 0.0541
# Epoch 00100: saving model to /content/gdrive/My Drive/bsc/Final/Transformers/cp.ckpt
# Training: epoch 99 ends at 10:01:24.336125
# sample text via predict :
# رهنمون کام کام زن زن کام کام ناپدید ناپدید ناپدید ناپدید زن زن ناپدید زن ناپدید ناپدید ناپدید ناپدید ناپدید
# saving loss
# 9921/9921 [==============================] - 142s 14ms/sample - loss: 0.0541 - val_loss: 0.3838
